# %%
# Indian Startup Datatset

# %%
# Module Alization (Import numpy,pandas,matplotlib,seaborn)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read Dataset(Excel-xlsx File)

# %%
data = pd.read_excel('Indian_Startup.xlsx')
data
# Out:
#          Company/Brand  Founded Headquarters  \
# 0         CollegeDekho   2015.0      Gurgaon
# 1                 BOX8   2012.0       Mumbai
# 2                Simpl   2015.0    Bangalore
# 3          8i Ventures   2018.0       Mumbai
# 4            PayGlocal   2021.0    Bangalore
# ...                ...      ...          ...
# 1204          HobSpace   2019.0       Mumbai
# 1205           DcodeAI   2020.0    New Delhi
# 1206  Biocon Biologics   1978.0    Bangalore
# 1207        KiranaKart   2020.0       Mumbai
# 1208             Meddo   2018.0      Gurgaon
#
#                                 Sector  \
# 0                           E-learning
# 1                     Food & Beverages
# 2                    Consumer Services
# 3     Venture Capital & Private Equity
# 4                   Financial Services
# ...                                ...
# 1204                            EdTech
# 1205                            EdTech
# 1206                     BioTechnology
# ...

# %%
# Fetch first 5 record from dataset

# %%
data.head()
# Out:
#   Company/Brand  Founded Headquarters                            Sector  \
# 0  CollegeDekho   2015.0      Gurgaon                        E-learning
# 1          BOX8   2012.0       Mumbai                  Food & Beverages
# 2         Simpl   2015.0    Bangalore                 Consumer Services
# 3   8i Ventures   2018.0       Mumbai  Venture Capital & Private Equity
# 4     PayGlocal   2021.0    Bangalore                Financial Services
#
#                                         What it does  \
# 0  Collegedekho.com is Student’s Partner, Friend ...
# 1                   India's Largest Desi Meals Brand
# 2  Simpl empowers merchants to build trusted rela...
# 3  8i is a Mumbai & Bangalore based early stage f...
# 4  PayGlocal is a FinTech solving for global paym...
#
#                                         Founder/s  \
# 0                                    Ruchir Arora
# 1                          Anshul Gupta, Amit Raj
# 2                        Nitya, Chaitra Chidanand
# ...

# %%
# Fetch last 5 records from dataset

# %%
data.tail()
# Out:
#          Company/Brand  Founded Headquarters         Sector  \
# 1204          HobSpace   2019.0       Mumbai         EdTech
# 1205           DcodeAI   2020.0    New Delhi         EdTech
# 1206  Biocon Biologics   1978.0    Bangalore  BioTechnology
# 1207        KiranaKart   2020.0       Mumbai     E-commerce
# 1208             Meddo   2018.0      Gurgaon     Healthcare
#
#                                            What it does  \
# 1204  HobSpace is a platform for extra-curricular ac...
# 1205       EMPOWER LEARNERS TO BE FUTURE READY USING AI
# 1206  Biocon is a fully integrated pure play biosimi...
# 1207  A better model for instant grocery delivery in...
# 1208   Meddo is an end-to-end medical services provider
#
#                            Founder/s                        Investor/s  \
# 1204    Priya Goel Sheth, Harsh Jain  Siddharth Bhaskar Shah, Upsparks
# 1205  Kartik Sharma, Ashish Aggarwal                           S Chand
# ...

# %%
# check number of rows and number of colums present in dataset

# %%
data.shape
# Out:
# (1209, 10)

# %%
# check how many colums are present in dataset

# %%
data.columns
# Out:
# Index(['Company/Brand', 'Founded', 'Headquarters', 'Sector', 'What it does',
#        'Founder/s', 'Investor/s', 'Amount', 'Stage', 'Date'],
#       dtype='object')

# %%
# Information about dataset like columns name, counts and datatype

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1209 non-null   object
#  1   Founded        1208 non-null   float64
#  2   Headquarters   1208 non-null   object
#  3   Sector         1209 non-null   object
#  4   What it does   1209 non-null   object
#  5   Founder/s      1205 non-null   object
#  6   Investor/s     1147 non-null   object
#  7   Amount         1206 non-null   object
#  8   Stage          781 non-null    object
#  9   Date           1209 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 94.6+ KB

# %%
# Descriptive summary of dataset

# %%
data.describe()
# Out:
#            Founded
# count  1208.000000
# mean   2016.655629
# std       4.517364
# min    1963.000000
# 25%    2015.000000
# 50%    2018.000000
# 75%    2020.000000
# max    2021.000000

# %%
# check is any NA/Null Value prestent in dataset or not

# %%
#data.isnull()  OR
data.isna()
# Out:
#       Company/Brand  Founded  Headquarters  Sector  What it does  Founder/s  \
# 0             False    False         False   False         False      False
# 1             False    False         False   False         False      False
# 2             False    False         False   False         False      False
# 3             False    False         False   False         False      False
# 4             False    False         False   False         False      False
# ...             ...      ...           ...     ...           ...        ...
# 1204          False    False         False   False         False      False
# 1205          False    False         False   False         False      False
# 1206          False    False         False   False         False      False
# 1207          False    False         False   False         False      False
# 1208          False    False         False   False         False      False
#
#       Investor/s  Amount  Stage   Date
# ...

# %%
# Count total NA/Null values in datase

# %%
# data.isnull().sum()   OR
data.isna().sum()
# Out:
# Company/Brand      0
# Founded            1
# Headquarters       1
# Sector             0
# What it does       0
# Founder/s          4
# Investor/s        62
# Amount             3
# Stage            428
# Date               0
# dtype: int64

# %%
# In above analysis Stage column contains most NA value so better solution is delete/drop it. 
# Delete/drop Stage column

# %%
data.drop('Stage', axis=1) # here it drops Stage coulmn temporary (Not Inplace)
# Out:
#          Company/Brand  Founded Headquarters  \
# 0         CollegeDekho   2015.0      Gurgaon
# 1                 BOX8   2012.0       Mumbai
# 2                Simpl   2015.0    Bangalore
# 3          8i Ventures   2018.0       Mumbai
# 4            PayGlocal   2021.0    Bangalore
# ...                ...      ...          ...
# 1204          HobSpace   2019.0       Mumbai
# 1205           DcodeAI   2020.0    New Delhi
# 1206  Biocon Biologics   1978.0    Bangalore
# 1207        KiranaKart   2020.0       Mumbai
# 1208             Meddo   2018.0      Gurgaon
#
#                                 Sector  \
# 0                           E-learning
# 1                     Food & Beverages
# 2                    Consumer Services
# 3     Venture Capital & Private Equity
# 4                   Financial Services
# ...                                ...
# 1204                            EdTech
# 1205                            EdTech
# 1206                     BioTechnology
# ...

# %%
data #(10- columns present now)
#In order to drop Stage column permanantly, we should do Inplace=True
# Out:
#          Company/Brand  Founded Headquarters  \
# 0         CollegeDekho   2015.0      Gurgaon
# 1                 BOX8   2012.0       Mumbai
# 2                Simpl   2015.0    Bangalore
# 3          8i Ventures   2018.0       Mumbai
# 4            PayGlocal   2021.0    Bangalore
# ...                ...      ...          ...
# 1204          HobSpace   2019.0       Mumbai
# 1205           DcodeAI   2020.0    New Delhi
# 1206  Biocon Biologics   1978.0    Bangalore
# 1207        KiranaKart   2020.0       Mumbai
# 1208             Meddo   2018.0      Gurgaon
#
#                                 Sector  \
# 0                           E-learning
# 1                     Food & Beverages
# 2                    Consumer Services
# 3     Venture Capital & Private Equity
# 4                   Financial Services
# ...                                ...
# 1204                            EdTech
# 1205                            EdTech
# 1206                     BioTechnology
# ...

# %%
data.drop('Stage', axis = 1, inplace= True) # Permanantly delete/drop Stage column (NA/Null Values) from dataset

# %%
data     #(9-columns present now)
# Out:
#          Company/Brand  Founded Headquarters  \
# 0         CollegeDekho   2015.0      Gurgaon
# 1                 BOX8   2012.0       Mumbai
# 2                Simpl   2015.0    Bangalore
# 3          8i Ventures   2018.0       Mumbai
# 4            PayGlocal   2021.0    Bangalore
# ...                ...      ...          ...
# 1204          HobSpace   2019.0       Mumbai
# 1205           DcodeAI   2020.0    New Delhi
# 1206  Biocon Biologics   1978.0    Bangalore
# 1207        KiranaKart   2020.0       Mumbai
# 1208             Meddo   2018.0      Gurgaon
#
#                                 Sector  \
# 0                           E-learning
# 1                     Food & Beverages
# 2                    Consumer Services
# 3     Venture Capital & Private Equity
# 4                   Financial Services
# ...                                ...
# 1204                            EdTech
# 1205                            EdTech
# 1206                     BioTechnology
# ...

# %%
data.head() # Fetching top 5 records for analysis
# Out:
#   Company/Brand  Founded Headquarters                            Sector  \
# 0  CollegeDekho   2015.0      Gurgaon                        E-learning
# 1          BOX8   2012.0       Mumbai                  Food & Beverages
# 2         Simpl   2015.0    Bangalore                 Consumer Services
# 3   8i Ventures   2018.0       Mumbai  Venture Capital & Private Equity
# 4     PayGlocal   2021.0    Bangalore                Financial Services
#
#                                         What it does  \
# 0  Collegedekho.com is Student’s Partner, Friend ...
# 1                   India's Largest Desi Meals Brand
# 2  Simpl empowers merchants to build trusted rela...
# 3  8i is a Mumbai & Bangalore based early stage f...
# 4  PayGlocal is a FinTech solving for global paym...
#
#                                         Founder/s  \
# 0                                    Ruchir Arora
# 1                          Anshul Gupta, Amit Raj
# 2                        Nitya, Chaitra Chidanand
# ...

# %%
# Lets take Categorical Column

# %%
# count the total unique records and its frequency present in Headquarters column

# %%
data['Headquarters']
# Out:
# 0         Gurgaon
# 1          Mumbai
# 2       Bangalore
# 3          Mumbai
# 4       Bangalore
#           ...
# 1204       Mumbai
# 1205    New Delhi
# 1206    Bangalore
# 1207       Mumbai
# 1208      Gurgaon
# Name: Headquarters, Length: 1209, dtype: object

# %%
data['Headquarters'].value_counts()
# Out:
# Bangalore             426
# Mumbai                203
# Gurugram              155
# New Delhi             144
# Pune                   47
#                      ...
# Gandhinagar             1
# Silvassa                1
# Thiruvananthapuram      1
# Faridabad               1
# Telangana               1
# Name: Headquarters, Length: 70, dtype: int64

# %%
# I want only top 5 headquarters from above

# %%
data['Headquarters'].value_counts().head()
# Out:
# Bangalore    426
# Mumbai       203
# Gurugram     155
# New Delhi    144
# Pune          47
# Name: Headquarters, dtype: int64

# %%
# Convert result into DataFrame

# %%
top_5_Headquarters = pd.DataFrame(data['Headquarters'].value_counts().head())
top_5_Headquarters
# Out:
#            Headquarters
# Bangalore           426
# Mumbai              203
# Gurugram            155
# New Delhi           144
# Pune                 47

# %%
# Plot Bar Chart for the same using seaborn library

# %%
sns.barplot(data = data, x = top_5_Headquarters.index, y = top_5_Headquarters['Headquarters'] )
plt.title('Top 5 Headquarters')
plt.show()

# %%
# From above analysis we can summerize- Banglore city is top to start startups in india than anyother city.

# %%
# Now analyse on Sector column

# %%
data['Sector'].value_counts() # Counting total values
# Out:
# FinTech                   121
# EdTech                    102
# Financial Services         61
# Food & Beverages           37
# E-commerce                 37
#                          ...
# Wholesale                   1
# Automobile                  1
# Environmental Services      1
# Merchandise                 1
# Fashion & Lifestyle         1
# Name: Sector, Length: 256, dtype: int64

# %%
data['Sector'].value_counts().head() # fetching first 5 record
# Out:
# FinTech               121
# EdTech                102
# Financial Services     61
# Food & Beverages       37
# E-commerce             37
# Name: Sector, dtype: int64

# %%
# Convert it into DataFrame

# %%
top_5_Sectors = pd.DataFrame(data['Sector'].value_counts().head())
top_5_Sectors
# Out:
#                     Sector
# FinTech                121
# EdTech                 102
# Financial Services      61
# Food & Beverages        37
# E-commerce              37

# %%
top_5_Sectors.values # Check only values
# Out:
# array([[121],
#        [102],
#        [ 61],
#        [ 37],
#        [ 37]], dtype=int64)

# %%
top_5_Sectors.index # check only index
# Out:
# Index(['FinTech', 'EdTech', 'Financial Services', 'Food & Beverages',
#        'E-commerce'],
#       dtype='object')

# %%
# Plot Bar Chart for the same using seaborn library

# %%
plt.figure(figsize=(12,7))
sns.barplot(data= data, x = top_5_Sectors.index ,y= top_5_Sectors['Sector'])
plt.title('Top 5 Secotrs for Indian Startups')
plt.xticks=130
plt.show()

# %%
# From above analysis we can summerize- In FinTech sector more startups are established in last few years.

# %%
# Now lets take numerical columns

# %%
data
# Out:
#          Company/Brand  Founded Headquarters  \
# 0         CollegeDekho   2015.0      Gurgaon
# 1                 BOX8   2012.0       Mumbai
# 2                Simpl   2015.0    Bangalore
# 3          8i Ventures   2018.0       Mumbai
# 4            PayGlocal   2021.0    Bangalore
# ...                ...      ...          ...
# 1204          HobSpace   2019.0       Mumbai
# 1205           DcodeAI   2020.0    New Delhi
# 1206  Biocon Biologics   1978.0    Bangalore
# 1207        KiranaKart   2020.0       Mumbai
# 1208             Meddo   2018.0      Gurgaon
#
#                                 Sector  \
# 0                           E-learning
# 1                     Food & Beverages
# 2                    Consumer Services
# 3     Venture Capital & Private Equity
# 4                   Financial Services
# ...                                ...
# 1204                            EdTech
# 1205                            EdTech
# 1206                     BioTechnology
# ...

# %%
# In dataset Founded (Startup Establishment) is numerical column
# Lets take it for analysis

# %%
data['Founded']
# Out:
# 0       2015.0
# 1       2012.0
# 2       2015.0
# 3       2018.0
# 4       2021.0
#          ...
# 1204    2019.0
# 1205    2020.0
# 1206    1978.0
# 1207    2020.0
# 1208    2018.0
# Name: Founded, Length: 1209, dtype: float64

# %%
data['Founded'].isna().sum() # here 1 NA value present so fill it with value zero
# Out:
# 1

# %%
data['Founded'] = data['Founded'].fillna(0) # here NA value is replce with zero

# %%
data['Founded'].isna().sum()
# Out:
# 0

# %%
data['Founded'] # This is numberical but contains float value, lets change it into integer
# Out:
# 0       2015.0
# 1       2012.0
# 2       2015.0
# 3       2018.0
# 4       2021.0
#          ...
# 1204    2019.0
# 1205    2020.0
# 1206    1978.0
# 1207    2020.0
# 1208    2018.0
# Name: Founded, Length: 1209, dtype: float64

# %%
data['Founded'] = data['Founded'].astype(int)
data['Founded']
# Out:
# 0       2015
# 1       2012
# 2       2015
# 3       2018
# 4       2021
#         ...
# 1204    2019
# 1205    2020
# 1206    1978
# 1207    2020
# 1208    2018
# Name: Founded, Length: 1209, dtype: int32

# %%
data['Founded'].value_counts()
# Out:
# 2020    237
# 2019    177
# 2018    143
# 2015    129
# 2016    118
# 2017    112
# 2021     76
# 2014     57
# 2011     34
# 2012     31
# 2013     22
# 2008     15
# 2010     14
# 2009      9
# 2000      6
# 2007      6
# 2006      3
# 1994      2
# 1989      2
# 2004      2
# 1998      2
# 2002      2
# 1999      2
# 2005      1
# 1963      1
# 0         1
# 2003      1
# 1993      1
# 1991      1
# 1984      1
# 1978      1
# Name: Founded, dtype: int64

# %%
data['Founded'].value_counts().head() # Fetch top 5 years where more startups are present
# Out:
# 2020    237
# 2019    177
# 2018    143
# 2015    129
# 2016    118
# Name: Founded, dtype: int64

# %%
top_5_Startup_Years = pd.DataFrame(data['Founded'].value_counts().head())
top_5_Startup_Years
# Out:
#       Founded
# 2020      237
# 2019      177
# 2018      143
# 2015      129
# 2016      118

# %%
top_5_Startup_Years.index
# Out:
# Int64Index([2020, 2019, 2018, 2015, 2016], dtype='int64')

# %%
top_5_Startup_Years.values
# Out:
# array([[237],
#        [177],
#        [143],
#        [129],
#        [118]], dtype=int64)

# %%
sns.barplot(data = data, x = top_5_Startup_Years.index, y = top_5_Startup_Years['Founded'])
plt.title('Top 5 years')
plt.show()

# %%
# From Above analysis we can summerize- In year 2020 more number of startups are established in India

# %%
plt.figure(figsize = (17,8))
sns.barplot(x = data['Founded'],y=data.index)
plt.xticks(90)
plt.title('Yearwise Startups')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1128/2741555048.py in <module>
#       1 plt.figure(figsize = (17,8))
#       2 sns.barplot(x = data['Founded'],y=data.index)
# ----> 3 plt.xticks(90)
#       4 plt.title('Yearwise Startups')
#       5 plt.show()
#
# TypeError: 'int' object is not callable
